# %%
import re
import os
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn

# %%
os.chdir('C:/English_paper')
os.getcwd()
# Out:
# 'C:\\English_paper'

# %%
def clean_text(text):
    '''Clean text by removing unnecessary characters and altering the format of words.'''

    text = re.sub(r"'m", "am", text)
    text = re.sub(r"\'re", "are", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'till", "until", text)
    text = re.sub('du n no', "do n't know", text)
    text = re.sub('gon na', 'going to', text)
    text = re.sub('cos', 'because', text)
    text = re.sub(r"[()\#/_@;:<>{}`+=~|]", "", text)
    
    return text

# %%
def correction(texted):
    ''' change wrong lemmatized words into correct one'''
    
    error=["wa","are","ha","am"]
    if texted in error:
        texted = re.sub("wa","be",texted)
        texted = re.sub("are","be",texted)
        texted = re.sub("ha","have",texted)
        texted = re.sub("cos","because",texted)
        texted = re.sub("am","be",texted)
        
    return texted

# %%
giga3000_corpus=open('giga3000.txt','r',encoding='utf-8').readlines()
giga3000_corpus=[i.strip().lower() for i in giga3000_corpus]
giga3000_corpus=[clean_text(x) for x in giga3000_corpus]
giga3000_corpus=[re.findall('\w+',i) for i in giga3000_corpus]

# %%
os.chdir('C:/OneStop/Adv')
adv_data_path=os.listdir()
adv_data=[]
for i in adv_data_path[1:]:
    adv_data.append(open(i,encoding='utf-8').read().strip().lower().replace('\ufeff',''))

adv_data=[i.split('\n') for i in adv_data]
adv_data=[clean_text(j) for i in adv_data for j in i]
adv_data=[re.findall('\w+',i) for i in adv_data]

# %%
os.chdir('C:/OneStop/Int')
Int_data_path=os.listdir()

Int_data=[]
for i in Int_data_path[1:]:
    Int_data.append(open(i,encoding='utf-8').read().strip().lower().replace('\ufeff',''))

Int_data=[i.split('\n') for i in Int_data]
Int_data=[clean_text(j) for i in Int_data for j in i]
Int_data=[re.findall('\w+',i) for i in Int_data]

# %%
os.chdir('C:/OneStop/Ele')
Ele_data_path=os.listdir()
Ele_data=[]
for i in Ele_data_path[1:]:
    Ele_data.append(open(i,encoding='utf-8').read().strip().lower().replace('\ufeff',''))

Ele_data=[i.split('\n') for i in Ele_data]
Ele_data=[clean_text(j) for i in Ele_data for j in i]
Ele_data=[re.findall('\w+',i) for i in Ele_data]

# %%
os.chdir('C:/Users/gartl/Documents/MWE level list')
phrase=open('lemma_MWE_list.txt','r',encoding='utf-8').readlines()
phrase=[i.strip() for i in phrase]
print(phrase[:10])
# Out:
# ['fall into line with', 'suck me suck me into', 'lumber us with', 'them rock', 'right here and now', 'look that up', 'how come', 'their decline years', 'pull that together', 'pull this out of the bag']

# %%
level1=open('MWE_level1.txt','r',encoding='utf-8').readlines()
level1=[i.strip().split('\t')[0].replace('_',' ') for i in level1]

level2=open('MWE_level2.txt','r',encoding='utf-8').readlines()
level2=[i.strip().split('\t')[0].replace('_',' ') for i in level2]

level3=open('MWE_level3.txt','r',encoding='utf-8').readlines()
level3=[i.strip().split('\t')[0].replace('_',' ') for i in level3]

level4=open('MWE_level4.txt','r',encoding='utf-8').readlines()
level4=[i.strip().split('\t')[0].replace('_',' ') for i in level4]

level5=open('MWE_level5.txt','r',encoding='utf-8').readlines()
level5=[i.strip().split('\t')[0].replace('_',' ') for i in level5]

level6=open('MWE_level6.txt','r',encoding='utf-8').readlines()
level6=[i.strip().split('\t')[0].replace('_',' ') for i in level6]

level7=open('MWE_level7.txt','r',encoding='utf-8').readlines()
level7=[i.strip().split('\t')[0].replace('_',' ') for i in level7]

level8=open('MWE_level8.txt','r',encoding='utf-8').readlines()
level8=[i.strip().split('\t')[0].replace('_',' ') for i in level8]

level9=open('MWE_level9.txt','r',encoding='utf-8').readlines()
level9=[i.strip().split('\t')[0].replace('_',' ') for i in level9]

level10=open('MWE_level10.txt','r',encoding='utf-8').readlines()
level10=[i.strip().split('\t')[0].replace('_',' ') for i in level10]

level11=open('MWE_level11.txt','r',encoding='utf-8').readlines()
level11=[i.strip().split('\t')[0].replace('_',' ') for i in level11]

level12=open('MWE_level12.txt','r',encoding='utf-8').readlines()
level12=[i.strip().split('\t')[0].replace('_',' ') for i in level12]

level13=open('MWE_level13.txt','r',encoding='utf-8').readlines()
level13=[i.strip().split('\t')[0].replace('_',' ') for i in level13]

level14=open('MWE_level14.txt','r',encoding='utf-8').readlines()
level14=[i.strip().split('\t')[0].replace('_',' ') for i in level14]

level15=open('MWE_level15.txt','r',encoding='utf-8').readlines()
level15=[i.strip().split('\t')[0].replace('_',' ') for i in level15]

level16=open('MWE_level16.txt','r',encoding='utf-8').readlines()
level16=[i.strip().split('\t')[0].replace('_',' ') for i in level16]

level17=open('MWE_level17.txt','r',encoding='utf-8').readlines()
level17=[i.strip().split('\t')[0].replace('_',' ') for i in level17]

level18=open('MWE_level18.txt','r',encoding='utf-8').readlines()
level18=[i.strip().split('\t')[0].replace('_',' ') for i in level18]

level19=open('MWE_level19.txt','r',encoding='utf-8').readlines()
level19=[i.strip().split('\t')[0].replace('_',' ') for i in level19]

level20=open('MWE_level20.txt','r',encoding='utf-8').readlines()
level20=[i.strip().split('\t')[0].replace('_',' ') for i in level20]

# %%
'''find and bound phrases in whole corpus. 
this code bound longer phrases first because the number of longer phrases can be subsumed to the number of short phrases'''
def phrase_extractor(lemma_sentences):
    for i in range(len(lemma_sentences)):
        for j in range(len(lemma_sentences[i])-5):
            if lemma_sentences[i][j]+' '+lemma_sentences[i][j+1]+' '+lemma_sentences[i][j+2]+' '+lemma_sentences[i][j+3]+' '+lemma_sentences[i][j+4]+' '+lemma_sentences[i][j+5] in phrase:
                lemma_sentences[i][j]=lemma_sentences[i][j]+'_'+lemma_sentences[i][j+1]+'_'+lemma_sentences[i][j+2]+'_'+lemma_sentences[i][j+3]+'_'+lemma_sentences[i][j+4]+'_'+lemma_sentences[i][j+5]
                lemma_sentences[i][j+1] = ''
                lemma_sentences[i][j+2] = ''
                lemma_sentences[i][j+3] = ''
                lemma_sentences[i][j+4] = ''
                lemma_sentences[i][j+5] = ''
            if lemma_sentences[i][j]+' '+lemma_sentences[i][j+1]+' '+lemma_sentences[i][j+2]+' '+lemma_sentences[i][j+3]+' '+lemma_sentences[i][j+4] in phrase:
                lemma_sentences[i][j]=lemma_sentences[i][j]+'_'+lemma_sentences[i][j+1]+'_'+lemma_sentences[i][j+2]+'_'+lemma_sentences[i][j+3]+'_'+lemma_sentences[i][j+4]
                lemma_sentences[i][j+1] = ''
                lemma_sentences[i][j+2] = ''
                lemma_sentences[i][j+3] = ''
                lemma_sentences[i][j+4] = ''
            if lemma_sentences[i][j]+' '+lemma_sentences[i][j+1]+' '+lemma_sentences[i][j+2]+' '+lemma_sentences[i][j+3] in phrase:
                lemma_sentences[i][j]=lemma_sentences[i][j]+'_'+lemma_sentences[i][j+1]+'_'+lemma_sentences[i][j+2]+'_'+lemma_sentences[i][j+3]
                lemma_sentences[i][j+1] = ''
                lemma_sentences[i][j+2] = ''
                lemma_sentences[i][j+3] = ''
            if lemma_sentences[i][j]+' '+lemma_sentences[i][j+1]+' '+lemma_sentences[i][j+2] in phrase:
                lemma_sentences[i][j]=lemma_sentences[i][j]+'_'+lemma_sentences[i][j+1]+'_'+lemma_sentences[i][j+2]
                lemma_sentences[i][j+1] = ''
                lemma_sentences[i][j+2] = ''
            if lemma_sentences[i][j]+' '+lemma_sentences[i][j+1] in phrase:
                lemma_sentences[i][j] = lemma_sentences[i][j] + '_' + lemma_sentences[i][j + 1]
                lemma_sentences[i][j + 1] = ''
        if len(lemma_sentences[i])>4 and lemma_sentences[i][-5]+' '+lemma_sentences[i][-4]+' '+lemma_sentences[i][-3]+' '+lemma_sentences[i][-2]+' '+lemma_sentences[i][-1] in phrase:
            lemma_sentences[i][-5] = lemma_sentences[i][-5]+'_'+lemma_sentences[i][-4]+'_'+lemma_sentences[i][-3]+'_'+lemma_sentences[i][-2] + '_' + lemma_sentences[i][-1]
            lemma_sentences[i][-4] = ''
            lemma_sentences[i][-3] = ''
            lemma_sentences[i][-2] = ''
            lemma_sentences[i][-1] = ''
        if len(lemma_sentences[i])>3 and lemma_sentences[i][-4]+' '+lemma_sentences[i][-3]+' '+lemma_sentences[i][-2]+' '+lemma_sentences[i][-1] in phrase:
            lemma_sentences[i][-4] = lemma_sentences[i][-4]+'_'+lemma_sentences[i][-3]+'_'+lemma_sentences[i][-2] + '_' + lemma_sentences[i][-1]
            lemma_sentences[i][-3] = ''
            lemma_sentences[i][-2] =''
            lemma_sentences[i][-1] = ''
        if len(lemma_sentences[i])>2 and lemma_sentences[i][-3]+' '+lemma_sentences[i][-2]+' '+lemma_sentences[i][-1] in phrase:  ## to go 추가
            lemma_sentences[i][-3] = lemma_sentences[i][-3]+'_'+lemma_sentences[i][-2] + '_' + lemma_sentences[i][-1]
            lemma_sentences[i][-2] =''
            lemma_sentences[i][-1] = ''
        if len(lemma_sentences[i])>1 and lemma_sentences[i][-2]+' '+lemma_sentences[i][-1] in phrase:
            lemma_sentences[i][-2] = lemma_sentences[i][-2] + '_' + lemma_sentences[i][-1]
            lemma_sentences[i][-1] = ''
        ''' remove every blanks('') in each sentences'''
        while True:
            if '' in lemma_sentences[i]:
                lemma_sentences[i].remove('')
            else:
                break

    return lemma_sentences

# %%
''' lemmatize texts first then detect and bound phrases in texts'''
def phrase_extraction(sentences):
    clean_sentences = []
    for i in sentences:
        clean_sentence = []
        for j in i:
            clean_sentence.append(clean_text(j))
        clean_sentences.append(clean_sentence)
        
    lemmatize_sentences=[]
    for i in clean_sentences:
        lemmatize_sentence=[]
        for j in i:
            lemmatize_sentence.append(wn.morphy(j))
        lemmatize_sentences.append(lemmatize_sentence)

    for i,y in zip(lemmatize_sentences,clean_sentences):
        for j,x in enumerate(i):
            if x==None:
                i[j]=y[j]
    
    lemma_sentences=[]
    for i in lemmatize_sentences:
        lemma_sentence=[]
        for j in i:
            lemma_sentence.append(correction(j))
        lemma_sentences.append(lemma_sentence)
    
    
        
    return phrase_extractor(lemma_sentences)

# %%
file=phrase_extraction(giga3000_corpus)

# %%
vocab_list=[word for sentence in file for word in sentence]
vocab_lists=[vocab_list]

# %%
adv_file=phrase_extraction(adv_data)
int_file=phrase_extraction(Int_data)
ele_file=phrase_extraction(Ele_data)

# %%
adv_vocab_list=[word for sentence in adv_file for word in sentence]
int_vocab_list=[word for sentence in int_file for word in sentence]
ele_vocab_list=[word for sentence in ele_file for word in sentence]
adv_vocab_lists=[adv_vocab_list]
int_vocab_lists=[int_vocab_list]
ele_vocab_lists=[ele_vocab_list]

# %%
len([i for i in ele_vocab_list if re.search('_',i)!=None])
# Out:
# 1734

# %%
os.chdir('C:/Users/gartl/Documents/word level list')
base1=open('word_level1.txt',encoding='utf-8').readlines()
base1=[i.strip().split('\t')[0].lower() for i in base1]

base2=open('word_level2.txt',encoding='utf-8').readlines()
base2=[i.strip().split('\t')[0].lower() for i in base2]
base2=[i for i in base2 if i not in base1]

base3=open('word_level3.txt',encoding='utf-8').readlines()
base3=[i.strip().split('\t')[0].lower() for i in base3]
base3=[i for i in base3 if i not in base1+base2]

base4=open('word_level4.txt',encoding='utf-8').readlines()
base4=[i.strip().split('\t')[0].lower() for i in base4]
base4=[i for i in base4 if i not in base1+base2+base3]

base5=open('word_level5.txt',encoding='utf-8').readlines()
base5=[i.strip().split('\t')[0].lower() for i in base5]
base5=[i for i in base5 if i not in base1+base2+base3+base4]

base6=open('word_level6.txt',encoding='utf-8').readlines()
base6=[i.strip().split('\t')[0].lower() for i in base6]
base6=[i for i in base6 if i not in base1+base2+base3+base4+base5]

base7=open('word_level7.txt',encoding='utf-8').readlines()
base7=[i.strip().split('\t')[0].lower() for i in base7]
base7=[i for i in base7 if i not in base1+base2+base3+base4+base5+base6]


base8=open('word_level8.txt',encoding='utf-8').readlines()
base8=[i.strip().split('\t')[0].lower() for i in base8]
base8=[i for i in base8 if i not in base1+base2+base3+base4+base5+base6+base7]

base9=open('word_level9.txt',encoding='utf-8').readlines()
base9=[i.strip().split('\t')[0].lower() for i in base9]
base9=[i for i in base9 if i not in base1+base2+base3+base4+base5+base6+base7+base8]


base10=open('word_level10.txt',encoding='utf-8').readlines()
base10=[i.strip().split('\t')[0].lower() for i in base10]
base10=[i for i in base10 if i not in base1+base2+base3+base4+base5+base6+base7+base8+base9]

# %%
''' analyze a text difficulty by using MWE level list and BNC word level list'''
class phrase_vocab_list:
    def __init__(self,file):
        self.file = file
        
    def phrase_level_list(self):
        phrase_list=list([i for i in self.file if re.search('_',i)])
    
        phrase1=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level1]]
        phrase2=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level2]]
        phrase3=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level3]]
        phrase4=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level4]]
        phrase5=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level5]]
        phrase6=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level6]]
        phrase7=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level7]]
        phrase8=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level8]]
        phrase9=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level9]]
        phrase10=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level10]]
        phrase11=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level11]]
        phrase12=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level12]]
        phrase13=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level13]]
        phrase14=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level14]]
        phrase15=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level15]]
        phrase16=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level16]]
        phrase17=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level17]]
        phrase18=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level18]]
        phrase19=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level19]]
        phrase20=[[i.replace('_',' ') for i in phrase_list if i.replace('_',' ') in level20]]
    
        return phrase1+phrase2+phrase3+phrase4+phrase5+phrase6+phrase7+phrase8+phrase9+phrase10+phrase11+phrase12+phrase13+phrase14+phrase15+phrase16+phrase17+phrase18+phrase19+phrase20
    
    def vocab_level_list(self):
        vocab_list=list([i for i in self.file if re.search('_',i)==None])

        vocab1=[[i for i in vocab_list if i in base1]]
        vocab2=[[i for i in vocab_list if i in base2]]
        vocab3=[[i for i in vocab_list if i in base3]]
        vocab4=[[i for i in vocab_list if i in base4]]
        vocab5=[[i for i in vocab_list if i in base5]]
        vocab6=[[i for i in vocab_list if i in base6]]
        vocab7=[[i for i in vocab_list if i in base7]]
        vocab8=[[i for i in vocab_list if i in base8]]
        vocab9=[[i for i in vocab_list if i in base9]]
        vocab10=[[i for i in vocab_list if i in base10]]
    
        return vocab1+vocab2+vocab3+vocab4+vocab5+vocab6+vocab7+vocab8+vocab9+vocab10

    
    def __call__(self):
        return self.phrase_level_list, self.vocab_level_list

# %%
phrase_level=[]
#for i in vocab_lists:
    #phrase_level.append(phrase_vocab_list(i)()[0])
for i in vocab_lists:
    phrase_level.append(phrase_vocab_list(i)()[0])
    
vocab_level=[]
for i in vocab_lists:
    vocab_level.append(phrase_vocab_list(i)()[1])

# %%
adv_phrase_level=[]
#for i in vocab_lists:
    #phrase_level.append(phrase_vocab_list(i)()[0])
for i in adv_vocab_lists:
    adv_phrase_level.append(phrase_vocab_list(i)()[0])
    
adv_vocab_level=[]
for i in adv_vocab_lists:
    adv_vocab_level.append(phrase_vocab_list(i)()[1])

# %%
int_phrase_level=[]
#for i in vocab_lists:
    #phrase_level.append(phrase_vocab_list(i)()[0])
for i in int_vocab_lists:
    int_phrase_level.append(phrase_vocab_list(i)()[0])
    
int_vocab_level=[]
for i in int_vocab_lists:
    int_vocab_level.append(phrase_vocab_list(i)()[1])

# %%
ele_phrase_level=[]
#for i in vocab_lists:
    #phrase_level.append(phrase_vocab_list(i)()[0])
for i in ele_vocab_lists:
    ele_phrase_level.append(phrase_vocab_list(i)()[0])
    
ele_vocab_level=[]
for i in ele_vocab_lists:
    ele_vocab_level.append(phrase_vocab_list(i)()[1])

# %%
len([j for i in ele_phrase_level[0]() for j in i])
# Out:
# 1665

# %%
print(len([j for i in vocab_level[0]() for j in i]))
print(len([i for i in vocab_lists[0] if re.search('_',i)==None]))
# Out:
# 55176
# 70229

# %%
def text_stats(file_num): #list return version
    num_phrase='phrase: {:f}%'.format((len([j for i in phrase_level[file_num]() for j in i])/len(vocab_lists[file_num]))*100)
    num_vocab='vocab: {:f}%'.format((len([j for i in vocab_level[file_num]() for j in i])/len(vocab_lists[file_num]))*100)
    P1='phrase 1: {:f}%'.format((len(phrase_level[file_num]()[0])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P2='phrase 2: {:f}%'.format((len(phrase_level[file_num]()[1])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P3='phrase 3: {:f}%'.format((len(phrase_level[file_num]()[2])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P4='phrase 4: {:f}%'.format((len(phrase_level[file_num]()[3])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P5='phrase 5: {:f}%'.format((len(phrase_level[file_num]()[4])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P6='phrase 6: {:f}%'.format((len(phrase_level[file_num]()[5])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P7='phrase 7: {:f}%'.format((len(phrase_level[file_num]()[6])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P8='phrase 8: {:f}%'.format((len(phrase_level[file_num]()[7])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P9='phrase 9: {:f}%'.format((len(phrase_level[file_num]()[8])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P10='phrase 10: {:f}%'.format((len(phrase_level[file_num]()[9])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P11='phrase 11: {:f}%'.format((len(phrase_level[file_num]()[10])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P12='phrase 12: {:f}%'.format((len(phrase_level[file_num]()[11])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P13='phrase 13: {:f}%'.format((len(phrase_level[file_num]()[12])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P14='phrase 14: {:f}%'.format((len(phrase_level[file_num]()[13])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P15='phrase 15: {:f}%'.format((len(phrase_level[file_num]()[14])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P16='phrase 16: {:f}%'.format((len(phrase_level[file_num]()[15])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P17='phrase 17: {:f}%'.format((len(phrase_level[file_num]()[16])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P18='phrase 18: {:f}%'.format((len(phrase_level[file_num]()[17])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P19='phrase 19: {:f}%'.format((len(phrase_level[file_num]()[18])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    P20='phrase 20: {:f}%'.format((len(phrase_level[file_num]()[19])/len([j for i in phrase_level[file_num]() for j in i]))*100)
    
    L1='vocab 1: {:f}%'.format((len(vocab_level[file_num]()[0])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L2='vocab 2: {:f}%'.format((len(vocab_level[file_num]()[1])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L3='vocab 3: {:f}%'.format((len(vocab_level[file_num]()[2])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L4='vocab 4: {:f}%'.format((len(vocab_level[file_num]()[3])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L5='vocab 5: {:f}%'.format((len(vocab_level[file_num]()[4])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L6='vocab 6: {:f}%'.format((len(vocab_level[file_num]()[5])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L7='vocab 7: {:f}%'.format((len(vocab_level[file_num]()[6])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L8='vocab 8: {:f}%'.format((len(vocab_level[file_num]()[7])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L9='vocab 9: {:f}%'.format((len(vocab_level[file_num]()[8])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    L10='vocab 10: {:f}%'.format((len(vocab_level[file_num]()[9])/len([j for i in vocab_level[file_num]() for j in i]))*100)
    
    return num_phrase,num_vocab,P1,P2,P3,P4,P5,P6,P7,P8,P9,P10,P11,P12,P13,P14,P15,P16,P17,P18,P19,P20,L1,L2,L3,L4,L5,L6,L7,L8,L9,L10

# %%
stat=[]
for i in range(len(vocab_lists)):
    stat.append(text_stats(i))

stat[0]
# Out:
# ('phrase: 1.450474%',
#  'vocab: 77.324962%',
#  'phrase 1: 51.111111%',
#  'phrase 2: 13.913043%',
#  'phrase 3: 8.888889%',
#  'phrase 4: 7.729469%',
#  'phrase 5: 4.347826%',
#  'phrase 6: 2.222222%',
#  'phrase 7: 2.705314%',
#  'phrase 8: 2.608696%',
#  'phrase 9: 1.932367%',
#  'phrase 10: 1.159420%',
#  'phrase 11: 0.483092%',
#  'phrase 12: 0.289855%',
#  'phrase 13: 0.772947%',
#  'phrase 14: 0.289855%',
#  'phrase 15: 0.289855%',
#  'phrase 16: 0.193237%',
#  'phrase 17: 0.193237%',
#  'phrase 18: 0.483092%',
#  'phrase 19: 0.000000%',
#  'phrase 20: 0.386473%',
#  'vocab 1: 74.251486%',
#  'vocab 2: 9.705307%',
#  'vocab 3: 4.632449%',
#  'vocab 4: 3.206104%',
#  'vocab 5: 2.457590%',
#  'vocab 6: 1.613020%',
#  'vocab 7: 1.344788%',
#  'vocab 8: 1.268668%',
#  'vocab 9: 0.808322%',
#  'vocab 10: 0.712266%')

# %%
def adv_text_stats(file_num):  # list return version
    num_phrase = 'phrase: {:f}%'.format(
        (len([j for i in adv_phrase_level[file_num]() for j in i]) / len(adv_vocab_lists[file_num])) * 100)
    num_vocab = 'vocab: {:f}%'.format(
        (len([j for i in adv_vocab_level[file_num]() for j in i]) / len(adv_vocab_lists[file_num])) * 100)
    P1 = 'phrase 1: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[0]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P2 = 'phrase 2: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[1]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P3 = 'phrase 3: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[2]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P4 = 'phrase 4: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[3]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P5 = 'phrase 5: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[4]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P6 = 'phrase 6: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[5]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P7 = 'phrase 7: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[6]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P8 = 'phrase 8: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[7]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P9 = 'phrase 9: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[8]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P10 = 'phrase 10: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[9]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P11 = 'phrase 11: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[10]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P12 = 'phrase 12: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[11]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P13 = 'phrase 13: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[12]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P14 = 'phrase 14: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[13]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P15 = 'phrase 15: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[14]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P16 = 'phrase 16: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[15]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P17 = 'phrase 17: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[16]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P18 = 'phrase 18: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[17]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P19 = 'phrase 19: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[18]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)
    P20 = 'phrase 20: {:f}%'.format(
        (len(adv_phrase_level[file_num]()[19]) / len([j for i in adv_phrase_level[file_num]() for j in i])) * 100)

    L1 = 'vocab 1: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[0]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L2 = 'vocab 2: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[1]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L3 = 'vocab 3: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[2]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L4 = 'vocab 4: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[3]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L5 = 'vocab 5: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[4]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L6 = 'vocab 6: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[5]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L7 = 'vocab 7: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[6]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L8 = 'vocab 8: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[7]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L9 = 'vocab 9: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[8]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)
    L10 = 'vocab 10: {:f}%'.format(
        (len(adv_vocab_level[file_num]()[9]) / len([j for i in adv_vocab_level[file_num]() for j in i])) * 100)

    return num_phrase, num_vocab, P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15, P16, P17, P18, P19, P20, L1, L2, L3, L4, L5, L6, L7, L8, L9, L10

# %%
adv_stat=[]
for i in range(len(adv_vocab_lists)):
    adv_stat.append(adv_text_stats(i))

adv_stat[0]
# Out:
# ('phrase: 1.903332%',
#  'vocab: 83.374047%',
#  'phrase 1: 54.351507%',
#  'phrase 2: 14.663055%',
#  'phrase 3: 7.720962%',
#  'phrase 4: 5.824585%',
#  'phrase 5: 3.962072%',
#  'phrase 6: 3.352523%',
#  'phrase 7: 2.607518%',
#  'phrase 8: 1.727057%',
#  'phrase 9: 1.727057%',
#  'phrase 10: 1.219099%',
#  'phrase 11: 0.643413%',
#  'phrase 12: 0.338639%',
#  'phrase 13: 0.406366%',
#  'phrase 14: 0.237047%',
#  'phrase 15: 0.203183%',
#  'phrase 16: 0.338639%',
#  'phrase 17: 0.101592%',
#  'phrase 18: 0.270911%',
#  'phrase 19: 0.169319%',
#  'phrase 20: 0.135455%',
#  'vocab 1: 76.792368%',
#  'vocab 2: 8.856317%',
#  'vocab 3: 4.446712%',
#  'vocab 4: 2.888971%',
#  'vocab 5: 2.115126%',
#  'vocab 6: 1.485072%',
#  'vocab 7: 1.005767%',
#  'vocab 8: 1.103174%',
#  'vocab 9: 0.675665%',
#  'vocab 10: 0.630827%')

# %%
def int_text_stats(file_num):  # list return version
    num_phrase = 'phrase: {:f}%'.format(
        (len([j for i in int_phrase_level[file_num]() for j in i]) / len(int_vocab_lists[file_num])) * 100)
    num_vocab = 'vocab: {:f}%'.format(
        (len([j for i in int_vocab_level[file_num]() for j in i]) / len(int_vocab_lists[file_num])) * 100)
    P1 = 'phrase 1: {:f}%'.format(
        (len(int_phrase_level[file_num]()[0]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P2 = 'phrase 2: {:f}%'.format(
        (len(int_phrase_level[file_num]()[1]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P3 = 'phrase 3: {:f}%'.format(
        (len(int_phrase_level[file_num]()[2]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P4 = 'phrase 4: {:f}%'.format(
        (len(int_phrase_level[file_num]()[3]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P5 = 'phrase 5: {:f}%'.format(
        (len(int_phrase_level[file_num]()[4]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P6 = 'phrase 6: {:f}%'.format(
        (len(int_phrase_level[file_num]()[5]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P7 = 'phrase 7: {:f}%'.format(
        (len(int_phrase_level[file_num]()[6]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P8 = 'phrase 8: {:f}%'.format(
        (len(int_phrase_level[file_num]()[7]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P9 = 'phrase 9: {:f}%'.format(
        (len(int_phrase_level[file_num]()[8]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P10 = 'phrase 10: {:f}%'.format(
        (len(int_phrase_level[file_num]()[9]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P11 = 'phrase 11: {:f}%'.format(
        (len(int_phrase_level[file_num]()[10]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P12 = 'phrase 12: {:f}%'.format(
        (len(int_phrase_level[file_num]()[11]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P13 = 'phrase 13: {:f}%'.format(
        (len(int_phrase_level[file_num]()[12]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P14 = 'phrase 14: {:f}%'.format(
        (len(int_phrase_level[file_num]()[13]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P15 = 'phrase 15: {:f}%'.format(
        (len(int_phrase_level[file_num]()[14]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P16 = 'phrase 16: {:f}%'.format(
        (len(int_phrase_level[file_num]()[15]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P17 = 'phrase 17: {:f}%'.format(
        (len(int_phrase_level[file_num]()[16]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P18 = 'phrase 18: {:f}%'.format(
        (len(int_phrase_level[file_num]()[17]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P19 = 'phrase 19: {:f}%'.format(
        (len(int_phrase_level[file_num]()[18]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)
    P20 = 'phrase 20: {:f}%'.format(
        (len(int_phrase_level[file_num]()[19]) / len([j for i in int_phrase_level[file_num]() for j in i])) * 100)

    L1 = 'vocab 1: {:f}%'.format(
        (len(int_vocab_level[file_num]()[0]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L2 = 'vocab 2: {:f}%'.format(
        (len(int_vocab_level[file_num]()[1]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L3 = 'vocab 3: {:f}%'.format(
        (len(int_vocab_level[file_num]()[2]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L4 = 'vocab 4: {:f}%'.format(
        (len(int_vocab_level[file_num]()[3]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L5 = 'vocab 5: {:f}%'.format(
        (len(int_vocab_level[file_num]()[4]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L6 = 'vocab 6: {:f}%'.format(
        (len(int_vocab_level[file_num]()[5]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L7 = 'vocab 7: {:f}%'.format(
        (len(int_vocab_level[file_num]()[6]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L8 = 'vocab 8: {:f}%'.format(
        (len(int_vocab_level[file_num]()[7]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L9 = 'vocab 9: {:f}%'.format(
        (len(int_vocab_level[file_num]()[8]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)
    L10 = 'vocab 10: {:f}%'.format(
        (len(int_vocab_level[file_num]()[9]) / len([j for i in int_vocab_level[file_num]() for j in i])) * 100)

    return num_phrase, num_vocab, P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15, P16, P17, P18, P19, P20, L1, L2, L3, L4, L5, L6, L7, L8, L9, L10

# %%
int_stat=[]
for i in range(len(int_vocab_lists)):
    int_stat.append(int_text_stats(i))

int_stat[0]
# Out:
# ('phrase: 1.811280%',
#  'vocab: 84.396161%',
#  'phrase 1: 59.520697%',
#  'phrase 2: 14.422658%',
#  'phrase 3: 6.666667%',
#  'phrase 4: 4.923747%',
#  'phrase 5: 3.660131%',
#  'phrase 6: 2.657952%',
#  'phrase 7: 2.657952%',
#  'phrase 8: 1.350763%',
#  'phrase 9: 1.307190%',
#  'phrase 10: 1.220044%',
#  'phrase 11: 0.566449%',
#  'phrase 12: 0.174292%',
#  'phrase 13: 0.174292%',
#  'phrase 14: 0.043573%',
#  'phrase 15: 0.043573%',
#  'phrase 16: 0.130719%',
#  'phrase 17: 0.043573%',
#  'phrase 18: 0.261438%',
#  'phrase 19: 0.130719%',
#  'phrase 20: 0.043573%',
#  'vocab 1: 78.730070%',
#  'vocab 2: 8.601487%',
#  'vocab 3: 4.160471%',
#  'vocab 4: 2.664235%',
#  'vocab 5: 1.809510%',
#  'vocab 6: 1.277412%',
#  'vocab 7: 0.819189%',
#  'vocab 8: 0.868752%',
#  'vocab 9: 0.533969%',
#  'vocab 10: 0.534904%')

# %%
def ele_text_stats(file_num):  # list return version
    num_phrase = 'phrase: {:f}%'.format(
        (len([j for i in ele_phrase_level[file_num]() for j in i]) / len(ele_vocab_lists[file_num])) * 100)
    num_vocab = 'vocab_level: {:f}%'.format(
        (len([j for i in ele_vocab_level[file_num]() for j in i]) / len(ele_vocab_lists[file_num])) * 100)
    P1 = 'phrase 1: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[0]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P2 = 'phrase 2: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[1]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P3 = 'phrase 3: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[2]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P4 = 'phrase 4: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[3]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P5 = 'phrase 5: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[4]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P6 = 'phrase 6: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[5]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P7 = 'phrase 7: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[6]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P8 = 'phrase 8: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[7]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P9 = 'phrase 9: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[8]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P10 = 'phrase 10: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[9]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P11 = 'phrase 11: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[10]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P12 = 'phrase 12: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[11]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P13 = 'phrase 13: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[12]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P14 = 'phrase 14: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[13]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P15 = 'phrase 15: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[14]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P16 = 'phrase 16: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[15]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P17 = 'phrase 17: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[16]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P18 = 'phrase 18: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[17]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P19 = 'phrase 19: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[18]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)
    P20 = 'phrase 20: {:f}%'.format(
        (len(ele_phrase_level[file_num]()[19]) / len([j for i in ele_phrase_level[file_num]() for j in i])) * 100)

    L1 = 'vocab 1: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[0]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L2 = 'vocab 2: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[1]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L3 = 'vocab 3: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[2]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L4 = 'vocab 4: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[3]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L5 = 'vocab 5: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[4]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L6 = 'vocab 6: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[5]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L7 = 'vocab 7: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[6]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L8 = 'vocab 8: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[7]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L9 = 'vocab 9: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[8]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)
    L10 = 'vocab 10: {:f}%'.format(
        (len(ele_vocab_level[file_num]()[9]) / len([j for i in ele_vocab_level[file_num]() for j in i])) * 100)

    return num_phrase, num_vocab, P1, P2, P3, P4, P5, P6, P7, P8, P9, P10, P11, P12, P13, P14, P15, P16, P17, P18, P19, P20, L1, L2, L3, L4, L5, L6, L7, L8, L9, L10

# %%
ele_stat=[]
for i in range(len(ele_vocab_lists)):
    ele_stat.append(ele_text_stats(i))

ele_stat[0]
# Out:
# ('phrase: 1.650967%',
#  'vocab_level: 84.275657%',
#  'phrase 1: 65.405405%',
#  'phrase 2: 13.753754%',
#  'phrase 3: 6.246246%',
#  'phrase 4: 3.843844%',
#  'phrase 5: 3.243243%',
#  'phrase 6: 1.981982%',
#  'phrase 7: 2.102102%',
#  'phrase 8: 0.840841%',
#  'phrase 9: 0.720721%',
#  'phrase 10: 0.660661%',
#  'phrase 11: 0.360360%',
#  'phrase 12: 0.120120%',
#  'phrase 13: 0.120120%',
#  'phrase 14: 0.000000%',
#  'phrase 15: 0.060060%',
#  'phrase 16: 0.180180%',
#  'phrase 17: 0.060060%',
#  'phrase 18: 0.180180%',
#  'phrase 19: 0.060060%',
#  'phrase 20: 0.060060%',
#  'vocab 1: 81.059394%',
#  'vocab 2: 7.916039%',
#  'vocab 3: 3.721527%',
#  'vocab 4: 2.304923%',
#  'vocab 5: 1.541322%',
#  'vocab 6: 1.031862%',
#  'vocab 7: 0.684770%',
#  'vocab 8: 0.817724%',
#  'vocab 9: 0.425922%',
#  'vocab 10: 0.496517%')

# %%
ele_vocab_lists[0]
# Out:
# ['when',
#  'you_see',
#  'the',
#  'word',
#  'amazon',
#  'what',
#  's',
#  'the',
#  'first_thing',
#  'you',
#  'think_of',
#  'the',
#  'world',
#  's',
#  'big',
#  'forest',
#  'the',
#  'long',
#  'river',
#  'or',
#  'the',
#  'large',
#  'internet',
#  'shop',
#  'and',
#  'which',
#  'do',
#  'you',
#  'think',
#  'be',
#  'most',
#  'important',
#  'these',
#  'be',
#  'the',
#  'question',
#  'in',
#  'a',
#  'debate',
#  'about',
#  'the',
#  'internet',
#  'brazil',
#  'and',
#  'peru',
#  'have',
#  'make',
#  'objection',
#  'to',
#  'a',
#  'bid',
#  'make',
#  'by',
#  'the',
#  'us',
#  'online',
#  'shop',
#  'for',
#  'the',
#  'domain',
#  'name',
#  'amazon',
#  'amazon',
#  'have',
#  'ask_for',
#  'it',
#  'company',
#  'name',
#  'to',
#  'be',
#  'a',
#  'top',
#  'level',
#  'domain',
#  'name',
#  'currently',
#  'com',
#  'but',
#  'the',
#  'south',
#  'american',
#  'government',
#  'say',
#  'this',
#  'would',
#  'stop',
#  'the',
#  'use',
#  'of',
#  'this',
#  'internet',
#  'address',
#  'for',
#  'environmental',
#  'protection',
#  'indigenous',
#  'right',
#  'and',
#  'other',
#  'public',
#  'interest',
#  'use',
#  'there',
#  'be',
#  'many',
#  'other',
#  'dispute',
#  'claim',
#  'to',
#  'names',
#  'include',
#  'patagonia',
#  'until',
#  'now',
#  'the',
#  'difference',
#  'between',
#  'commercial',
#  'governmental',
#  'and',
#  'other',
#  'type',
#  'of',
#  'identity',
#  'be',
#  'easy',
#  'to',
#  'see',
#  'in',
#  'every',
#  'internet',
#  'address',
#  'by',
#  'the',
#  'use',
#  'of',
#  'com',
#  'gov',
#  'and',
#  '20',
#  'other',
#  'category',
#  'but',
#  'soon',
#  'there',
#  'be',
#  'going',
#  'to',
#  'be',
#  'more',
#  'of',
#  'these',
#  'category',
#  'or',
#  'generic',
#  'top',
#  'level',
#  'domain',
#  'gtlds',
#  'as',
#  'they',
#  'be',
#  'technically',
#  'know',
#  'the',
#  'internet',
#  'corporation',
#  'for',
#  'assign',
#  'names',
#  'and',
#  'numbers',
#  'icann',
#  'have',
#  'have',
#  'bid',
#  'each',
#  'worth',
#  'almost',
#  '200',
#  '000',
#  'for',
#  'hundred',
#  'of',
#  'new',
#  'gtlds',
#  'to',
#  'add',
#  'to',
#  'the',
#  '22',
#  'that',
#  'we',
#  'use',
#  'already',
#  'amazon',
#  'have',
#  'apply',
#  'for',
#  'many',
#  'new',
#  'domain',
#  'include',
#  'shop',
#  'song',
#  'book',
#  'and',
#  'kindle',
#  'but',
#  'the',
#  'one',
#  'that',
#  'have',
#  'cause',
#  'most',
#  'discussion',
#  'be',
#  'it',
#  'application',
#  'for',
#  'amazon',
#  'brazil',
#  'and',
#  'peru',
#  'want',
#  'the',
#  'amazon',
#  'application',
#  'to',
#  'be',
#  'stop',
#  'they',
#  'say',
#  'that',
#  'a',
#  'private',
#  'company',
#  'should',
#  'not',
#  'have',
#  'a',
#  'name',
#  'that',
#  'be',
#  'also',
#  'the',
#  'name',
#  'of',
#  'an',
#  'important',
#  'geographical',
#  'area',
#  'allow',
#  'private',
#  'company',
#  'to',
#  'register',
#  'geographical',
#  'names',
#  'as',
#  'gtlds',
#  'to',
#  'profit_from',
#  'the',
#  'meaning',
#  'of',
#  'these',
#  'names',
#  'be',
#  'not',
#  'in',
#  'our',
#  'view',
#  'in',
#  'the',
#  'public',
#  'interest',
#  'the',
#  'brazilian',
#  'ministry',
#  'of',
#  'science',
#  'and',
#  'technology',
#  'say',
#  'brazil',
#  'say',
#  'other',
#  'member',
#  'of',
#  'the',
#  'amazon',
#  'cooperation',
#  'treaty',
#  'support',
#  'it',
#  'view',
#  'bolivia',
#  'colombia',
#  'ecuador',
#  'guyana',
#  'suriname',
#  'and',
#  'venezuela',
#  'there',
#  'have',
#  'also',
#  'be',
#  'other',
#  'objection',
#  'over',
#  'new',
#  'top',
#  'level',
#  'domain',
#  'that',
#  'use',
#  'geographical',
#  'or',
#  'cultural',
#  'names',
#  'argentina',
#  'be',
#  'unhappy',
#  'that',
#  'the',
#  'us',
#  'outdoor',
#  'clothing',
#  'retailer',
#  'patagonia',
#  'want',
#  'a',
#  'domain',
#  'name',
#  'that',
#  'have',
#  'be',
#  'know',
#  'far',
#  'longer',
#  'as',
#  'a',
#  'region',
#  'of',
#  'spectacular',
#  'beauty',
#  'argentina',
#  'reject',
#  'the',
#  'patagonia',
#  'request',
#  'for',
#  'a',
#  'new',
#  'generic',
#  'top',
#  'level',
#  'domain',
#  'patagonia',
#  'be',
#  'an',
#  'important',
#  'region',
#  'for',
#  'the',
#  'country',
#  's',
#  'economy',
#  'because',
#  'it',
#  'have',
#  'oil',
#  'fishing',
#  'mining',
#  'and',
#  'agriculture',
#  'resource',
#  'it',
#  'be',
#  'also',
#  'a',
#  'major',
#  'tourist',
#  'destination',
#  'they',
#  'will',
#  'discus',
#  'the',
#  'dispute',
#  'bid',
#  'again',
#  'at',
#  'a',
#  'meeting',
#  'of',
#  'icann',
#  's',
#  'governmental',
#  'advisory',
#  'committee',
#  'in',
#  'durban',
#  'in',
#  'july',
#  'the',
#  'first',
#  'new',
#  'domain',
#  'names',
#  'will',
#  'probably',
#  'be',
#  'in_use',
#  'before',
#  'the',
#  'end',
#  'of',
#  '2013',
#  'to',
#  'tourist',
#  'amsterdam',
#  'still',
#  'seem',
#  'very',
#  'liberal',
#  'recently',
#  'the',
#  'city',
#  's',
#  'mayor',
#  'tell',
#  'them',
#  'that',
#  'the',
#  'coffee',
#  'shop',
#  'that',
#  'sell',
#  'marijuana',
#  'would',
#  'stay',
#  'open',
#  'although',
#  'there',
#  'be',
#  'a',
#  'new',
#  'national',
#  'law',
#  'to',
#  'stop',
#  'drug',
#  'tourism',
#  'but',
#  'the',
#  'dutch',
#  'capital',
#  'have',
#  'a',
#  'plan',
#  'to',
#  'send',
#  'antisocial',
#  'neighbour',
#  'to',
#  'scum',
#  'village',
#  'make',
#  'from',
#  'shipping',
#  'container',
#  'and',
#  'so',
#  'maybe',
#  'now',
#  'people',
#  'won',
#  't',
#  'think',
#  'it',
#  'be',
#  'a',
#  'liberal',
#  'city',
#  'any_more',
#  'the',
#  'mayor',
#  'eberhard',
#  'van',
#  'd',
#  'laan',
#  'say',
#  'his',
#  'new',
#  'plan',
#  'to',
#  'solve',
#  'the',
#  'problem',
#  'of',
#  'antisocial',
#  'behaviour',
#  'will',
#  'becauset',
#  '810',
#  '000',
#  'the',
#  'plan',
#  'be',
#  'hope',
#  'to',
#  'protect',
#  'victim',
#  'of',
#  'abuse',
#  'and',
#  'homophobia',
#  'the',
#  'camp',
#  'where',
#  'antisocial',
#  'family',
#  'will',
#  'live_for',
#  'three',
#  'to',
#  'six',
#  'month',
#  'have',
#  'be',
#  'call',
#  'scum',
#  'village',
#  'because',
#  'last',
#  'year',
#  'geert',
#  'wilder',
#  'the',
#  'far',
#  'right',
#  'politician',
#  'say',
#  'that',
#  'offender',
#  'should',
#  'go_to',
#  'a',
#  'village',
#  'for',
#  'scum',
#  'bartho',
#  'boer',
#  'a',
#  'spokesman',
#  'for',
#  'the',
#  'mayor',
#  'say',
#  'that',
#  'the',
#  'plan',
#  'be',
#  'not',
#  'illiberal',
#  'we',
#  'want',
#  'to',
#  'defend',
#  'the',
#  'liberal',
#  'values',
#  'of',
#  'amsterdam',
#  'he',
#  'say',
#  'we',
#  'want',
#  'everyone',
#  'to',
#  'be',
#  'who',
#  'he',
#  'and',
#  'she',
#  'be',
#  'whether',
#  'they',
#  'be',
#  'gay',
#  'and',
#  'lesbian',
#  'or',
#  'try',
#  'to',
#  'stop',
#  'violence',
#  'and',
#  'be',
#  'then',
#  'victim',
#  'of',
#  'harassment',
#  'we',
#  'want',
#  'to',
#  'defend',
#  'them',
#  'accord',
#  'to',
#  'boer',
#  'the',
#  'village',
#  'be',
#  'not',
#  'for',
#  'a',
#  'problem',
#  'neighbour',
#  'who',
#  'have',
#  'the',
#  'stereo',
#  'too',
#  'loud',
#  'on',
#  'saturday',
#  'night',
#  'but',
#  'people',
#  'who',
#  'be',
#  'very',
#  'violent',
#  'and',
#  'in',
#  'a',
#  'clear',
#  'situation',
#  'where',
#  'a',
#  'victim',
#  'be',
#  'harass',
#  'again',
#  'and',
#  'again',
#  'people',
#  'found',
#  'guilty',
#  'of',
#  'violent',
#  'harassment',
#  'will',
#  'be',
#  'evict',
#  'from',
#  'their',
#  'home',
#  'and',
#  'put_in',
#  'temporary',
#  'home',
#  'include',
#  'shipping',
#  'container',
#  'in',
#  'industrial',
#  'area',
#  'of',
#  'the',
#  'city',
#  'we',
#  'call',
#  'it',
#  'a',
#  'living',
#  'container',
#  'say',
#  'boer',
#  'the',
#  'container',
#  'have',
#  'shower',
#  'and',
#  'kitchen',
#  'and',
#  'have',
#  'be_use',
#  'as',
#  'student',
#  'accommodation',
#  'they',
#  'be',
#  'going',
#  'to',
#  'use',
#  'the',
#  'container',
#  'because',
#  'they',
#  'want',
#  'to',
#  'show',
#  'that',
#  'if',
#  'people',
#  'be',
#  'antisocial',
#  'they',
#  'do',
#  'not',
#  'get',
#  'better',
#  'accommodation',
#  'one',
#  'dutch',
#  'newspaper',
#  'write',
#  'that',
#  'in',
#  'the',
#  '19th',
#  'century',
#  'antisocial',
#  'people',
#  'be',
#  'move_to',
#  'village',
#  'in',
#  'drenthe',
#  'and',
#  'overijssel',
#  'which',
#  'soon',
#  'become',
#  'slum',
#  'but',
#  'boer',
#  'say',
#  'that',
#  'the',
#  'government',
#  'have',
#  'learn',
#  'from',
#  'past',
#  'mistake',
#  'and',
#  'be',
#  'not',
#  'planning',
#  'to',
#  'put',
#  'antisocial',
#  'family',
#  'together',
#  'they',
#  'be',
#  'scum',
#  'house',
#  'not',
#  'scum',
#  'village',
#  'say',
#  'boer',
#  'because',
#  'we',
#  'don',
#  't',
#  'want',
#  'to',
#  'put',
#  'more_than',
#  'one',
#  'of',
#  'these',
#  'family',
#  'in',
#  'the',
#  'same',
#  'area',
#  'after',
#  'a',
#  'maximum',
#  'of',
#  'six',
#  'month',
#  'in',
#  'these',
#  'house',
#  'in',
#  'different',
#  'parts',
#  'of',
#  'the',
#  'city',
#  'the',
#  'family',
#  'will',
#  'get',
#  'permanent',
#  'home',
#  'the',
#  'city',
#  'government',
#  'expect',
#  'to',
#  'move',
#  'about',
#  'ten',
#  'family',
#  'a',
#  'year',
#  'which',
#  'start',
#  'in',
#  '2013',
#  'police',
#  'will',
#  'watch',
#  'the',
#  'temporary',
#  'accommodation',
#  'but',
#  'antisocial',
#  'family',
#  'will',
#  'also',
#  'be',
#  'able',
#  'to',
#  'see',
#  'doctor',
#  'and',
#  'social',
#  'worker',
#  'we',
#  'will',
#  'take_care_of',
#  'them',
#  'so',
#  'the',
#  'whole',
#  'situation',
#  'be',
#  'not',
#  'going',
#  'to',
#  'repeat',
#  'at',
#  'the',
#  'new',
#  'house',
#  'they',
#  'be',
#  'in',
#  'say',
#  'boer',
#  'anitta',
#  'a',
#  'music',
#  'star',
#  'from',
#  'brazil',
#  'have',
#  'million',
#  'of',
#  'fan',
#  'but',
#  'she',
#  'be',
#  'at',
#  'the',
#  'centre',
#  'of',
#  'a',
#  'debate',
#  'about',
#  'skin',
#  'colour',
#  'some',
#  'people',
#  'be',
#  'saying',
#  'that',
#  'anitta',
#  'have',
#  'to',
#  'give_up',
#  'her',
#  'black',
#  'skin',
#  'to',
#  'be',
#  'a',
#  'success',
#  'in',
#  'the',
#  'mostly',
#  'white',
#  'middle',
#  'class',
#  'market',
#  'the',
#  'debate',
#  'be',
#  'start',
#  'by',
#  'photograph',
#  'that',
#  'show',
#  'that',
#  'anitta',
#  's',
#  'skin',
#  'have',
#  'get',
#  'much',
#  'lighter',
#  'since',
#  'she',
#  'sign',
#  'a',
#  'music',
#  'deal',
#  'with',
#  'warner',
#  'in',
#  'the',
#  'first',
#  'photo',
#  'before',
#  'she',
#  'be',
#  'famous',
#  'she',
#  'look',
#  'dark',
#  'in',
#  'the_second',
#  'photo',
#  'a',
#  'marketing',
#  'photo',
#  'after',
#  'she',
#  'become',
#  'famous',
#  'she',
#  'seem',
#  'lighter',
#  'the',
#  'difference',
#  'have',
#  'start',
#  'a',
#  'discussion',
#  'about',
#  'whether',
#  'you',
#  'need',
#  'to',
#  'have',
#  'light',
#  'skin',
#  'to',
#  'be',
#  'a',
#  'success',
#  'in',
#  'brazil',
#  'born',
#  'larissa',
#  'de',
#  'macedo',
#  'machado',
#  'the',
#  'diva',
#  'to',
#  'be',
#  'be',
#  'a',
#  'church',
#  'chorister',
#  'in',
#  'her',
#  'childhood',
#  'in',
#  'her',
#  'teens',
#  'she',
#  'make',
#  'a',
#  'name',
#  'for',
#  'herself',
#  'in',
#  'rio',
#  ...]

# %%
print(len([j for i in ele_vocab_level[0]() for j in i]))
print(len([i for i in ele_vocab_lists[0]]))
# Out:
# 84992
# 100850

# %%
advanced=adv_stat[0][2:22]
advanced=[i.split(':')[1].strip() for i in advanced]
advanced=[i.replace('%','') for i in advanced]
advanced=[float(i)*0.01 for i in advanced]
intermediate=int_stat[0][2:22]
intermediate=[i.split(':')[1].strip() for i in intermediate]
intermediate=[i.replace('%','') for i in intermediate]
intermediate=[float(i)*0.01 for i in intermediate]
elementary=ele_stat[0][2:22]
elementary=[i.split(':')[1].strip() for i in elementary]
elementary=[i.replace('%','') for i in elementary]
elementary=[float(i)*0.01 for i in elementary]

# %%
import numpy as np
import matplotlib.pyplot as plt

label=['L1','L2','L3','L4','L5','L6','L7','L8','L9','L10',
           'L11','L12','L13','L14','L15','L16','L17','L18','L19','L20']
plt.plot(label,advanced, color='red')
plt.plot(label,intermediate, color='yellow')
plt.plot(label,elementary,color='')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     781                 self._set_gc_clip(gc)
#     782
# --> 783                 lc_rgba = mcolors.to_rgba(self._color, self._alpha)
#     784                 gc.set_foreground(lc_rgba, isRGBA=True)
#     785
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     175         rgba = None
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#     179             _colors_full_map.cache[c, alpha] = rgba
#
# c:\users\gartl\appdata\local\programs\python\python36\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     231         except ValueError:
#     232             pass
# --> 233         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     234     # tuple color.
#     235     c = np.array(c)
#
# ValueError: Invalid RGBA argument: ''

# %%
os.chdir('C:/Users/gartl/Downloads')
label=['L1','L2','L3','L4','L5','L6','L7','L8','L9','L10',
           'L11','L12','L13','L14','L15','L16','L17','L18','L19','L20']
x=np.arange(len(label))
plt.bar(x-0.24,elementary,label='elementary',width=0.24,color='blue')
plt.bar(x,intermediate,label='intermediate',width=0.24,color='green')
plt.bar(x+0.24,advanced,label='advanced',width=0.24,color='red')
plt.legend()
plt.xlabel('MWE level')
plt.xticks(x,label)
plt.ylabel('The percentage of MWEs in each level')
fig=plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()
fig.savefig('MWE level analysis.png')

# %%
os.chdir('C:/Users/gartl/Downloads')
label=['L20','L19','L18','L17','L16','L15','L14','L13','L12','L11',
           'L10','L9','L8','L7','L6','L5','L4','L3','L2','L1']

x=np.arange(len(label))
plt.barh(x+0.24,elementary[::-1],label='elementary',height=0.24,color='dodgerblue')
plt.barh(x,intermediate[::-1],label='intermediate',height=0.24,color='seagreen')
plt.barh(x-0.24,advanced[::-1],label='advanced',height=0.24,color='orangered')
plt.legend(loc='lower right',fontsize='18')
plt.xlim(0,1)
plt.ylabel('MWE level',fontsize='25')
plt.yticks(x,label,fontsize='20')
plt.xticks(fontsize='20')
plt.xlabel('The percentage of MWEs in each level',fontsize='25')
fig=plt.gcf()
fig.set_size_inches(15, 25)
plt.show()
fig.savefig('MWE level analysis.png')
